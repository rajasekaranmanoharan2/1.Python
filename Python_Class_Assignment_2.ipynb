# %%
from Python_Class_Assignment_1 import SubfieldsInAI, OddEven, ElegiblityForMarriage, FindPercent, triangle

SubfieldsInAI.Subfields()
OddEven.OddEven()
ElegiblityForMarriage.Elegible()
FindPercent.percentage()
triangle.triangle()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# Enter a number: 23
# 23 is Odd number
# Your Gender: M
# Your Age: 121
# 121 is eligiable for gender -  M
# Total : 148
# Percentage : 29.6
# Area of Triangle: 6.0
# Perimeter of Triangle: 52

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI
# 'HOPE AI'

# %%
input("Enter your name: ")
int(input("Enter your age: "))
input("Enter your school name: ")
input("Enter your drgree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru school
# Enter your drgree:  B.E CSE
# 'B.E CSE'

# %%
value1 = 43 
value2= 34 

print("a= ",value1)
print("b= ",value2)
print("add = ",value1+value2)
# Out:
# a=  43
# b=  34
# add =  77

# %%
value1 = 43 
value2= 34 

print("a= ",value1)
print("b= ",value2)
print("Sub = ",value1-value2)
# Out:
# a=  43
# b=  34
# Sub =  9

# %%
value1 = 63 
value2= 97 

print("a= ",value1)
print("b= ",value2)
print("Mul = ",value1*value2)
# Out:
# a=  63
# b=  97
# Mul =  6111

# %%
value1 = 76 
value2= 31 

print("a= ",value1)
print("b= ",value2)
print("Float Div = ",value1/value2)
# Out:
# a=  76
# b=  31
# Float Div =  2.4516129032258065

# %%
value1 = 76 
value2= 31 

print("a= ",value1)
print("b= ",value2)
print("Floor Div = ",value1//value2)
# Out:
# a=  76
# b=  31
# Floor Div =  2

# %%
value1 = 76 
value2= 31 

print("a= ",value1)
print("b= ",value2)
print("Modulo = ",value1%value2)
# Out:
# a=  76
# b=  31
# Modulo =  14

# %%
value1 = 4 
value2= 4 

print("a= ",value1)
print("b= ",value2)
print("Power = ",value1**value2)
# Out:
# a=  4
# b=  4
# Power =  256
